# %%
import pandas as pd
import numpy as np

# %%
prefix = '/content/drive'
from google.colab import drive
drive.mount(prefix, force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# First, let's do an Exploratory Data Analysis of the Occurrence file from the bird sounds dataset

# %%
# copy and paste the file path between the quotation marks below
file_path = ''

# %%
bird_occurrences = pd.read_csv(file_path)
bird_occurrences.head()
# Out:
# <ipython-input-4-d651bcc60f3b>:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   bird_occurrences = pd.read_csv(file_path)
#          id                                       occurrenceID catalogNumber  \
# 0      9@XC  https://data.biodiversitydata.nl/xeno-canto/ob...           XC9
# 1     99@XC  https://data.biodiversitydata.nl/xeno-canto/ob...          XC99
# 2   9999@XC  https://data.biodiversitydata.nl/xeno-canto/ob...        XC9999
# 3  99999@XC  https://data.biodiversitydata.nl/xeno-canto/ob...       XC99999
# 4  99998@XC  https://data.biodiversitydata.nl/xeno-canto/ob...       XC99998
#
#       basisOfRecord           collectionCode dynamicProperties  \
# 0  HumanObservation  Wildlife sounds - Birds               NaN
# 1  HumanObservation  Wildlife sounds - Birds               NaN
# 2  HumanObservation  Wildlife sounds - Birds               NaN
# 3  HumanObservation  Wildlife sounds - Birds               NaN
# 4  HumanObservation  Wildlife sounds - Birds               NaN
#
#   otherCatalogNumbers           genus specificEpithet infraspecificEpithet  \
# 0                 NaN      Synallaxis          azarae                media
# 1                 NaN          Turdus       hauxwelli                  NaN
# 2                 NaN      Myrmothera     campanisona              signata
# 3                 NaN      Glaucidium        peruanum                  NaN
# 4                 NaN  Eleoscytalopus     indigoticus                  NaN
#
#    ... verbatimEventDate                                         fieldNotes  \
# 0  ...        12-08-2002  two birds trip:http://www.cs.bris.ac.uk/home/p...
# 1  ...        01-10-2003   trip:http://www.cs.bris.ac.uk/home/planque/Peru/
# 2  ...        04-03-1998                                                NaN
# 3  ...          2011-7-5                                                NaN
# 4  ...        2011-10-14                                                NaN
#
#   behavior  sex lifeStage     preparations  \
# 0     song  NaN       NaN  field recording
# 1     song  NaN       NaN  field recording
# 2     song  NaN       NaN  field recording
# 3     song  NaN       NaN  field recording
# 4     song  NaN       NaN  field recording
#
#                                           references  \
# 0  https://data.biodiversitydata.nl/xeno-canto/ob...
# 1  https://data.biodiversitydata.nl/xeno-canto/ob...
# 2  https://data.biodiversitydata.nl/xeno-canto/ob...
# 3  https://data.biodiversitydata.nl/xeno-canto/ob...
# 4  https://data.biodiversitydata.nl/xeno-canto/ob...
#
#                                      Associated Taxa  \
# 0                                                NaN
# 1                                                NaN
# 2      has background sounds: Selenidera reinwardtii
# 3           has background sounds: Crypturellus soui
# 4  has background sounds: Pachyramphus castaneus|...
#
#                rightsHolder   license
# 0               Bob Planqué  CC BY-NC
# 1               Bob Planqué  CC BY-NC
# 2         Allen T. Chartier  CC BY-NC
# 3  Leonardo Ordóñez-Delgado  CC BY-NC
# 4         Rodrigo Dela Rosa  CC BY-NC
#
# [5 rows x 37 columns]

# %%
# find out if id is an index
# The processing tutorial says:
# "The fastest way to determine whether any single column is unique is
# to check whether the number of unique values in the candidate column equals the number of elements."
len(bird_occurrences['id'].unique()) == len(bird_occurrences['id'])
# Out:
# True

# %%
bird_occurrences.shape # number of rows and columns
# Out:
# (697734, 37)

# %%
bird_occurrences.size # number of elements
# Out:
# 25816158

# %%
bird_occurrences.columns
# Out:
# Index(['id', 'occurrenceID', 'catalogNumber', 'basisOfRecord',
#        'collectionCode', 'dynamicProperties', 'otherCatalogNumbers', 'genus',
#        'specificEpithet', 'infraspecificEpithet', 'scientificName',
#        'taxonRank', 'kingdom', 'family', 'higherClassification',
#        'nomenclaturalCode', 'identificationRemarks', 'vernacularName',
#        'longitudeDecimal', 'latitudeDecimal', 'geodeticDatum', 'country',
#        'locality', 'verbatimElevation', 'recordedBy', 'eventDate', 'eventTime',
#        'verbatimEventDate', 'fieldNotes', 'behavior', 'sex', 'lifeStage',
#        'preparations', 'references', 'Associated Taxa', 'rightsHolder',
#        'license'],
#       dtype='object')

# %%
bird_occurrences.dtypes
# Out:
# id                        object
# occurrenceID              object
# catalogNumber             object
# basisOfRecord             object
# collectionCode            object
# dynamicProperties         object
# otherCatalogNumbers       object
# genus                     object
# specificEpithet           object
# infraspecificEpithet      object
# scientificName            object
# taxonRank                 object
# kingdom                   object
# family                    object
# higherClassification      object
# nomenclaturalCode         object
# identificationRemarks     object
# vernacularName            object
# longitudeDecimal         float64
# latitudeDecimal          float64
# geodeticDatum             object
# country                   object
# locality                  object
# verbatimElevation         object
# recordedBy                object
# eventDate                 object
# eventTime                 object
# verbatimEventDate         object
# fieldNotes                object
# behavior                  object
# sex                       object
# lifeStage                 object
# preparations              object
# references                object
# Associated Taxa           object
# rightsHolder              object
# license                   object
# dtype: object

# %%
bird_occurrences.head() # first n rows. default n = 5
# Out:
#          id                                       occurrenceID catalogNumber  \
# 0      9@XC  https://data.biodiversitydata.nl/xeno-canto/ob...           XC9
# 1     99@XC  https://data.biodiversitydata.nl/xeno-canto/ob...          XC99
# 2   9999@XC  https://data.biodiversitydata.nl/xeno-canto/ob...        XC9999
# 3  99999@XC  https://data.biodiversitydata.nl/xeno-canto/ob...       XC99999
# 4  99998@XC  https://data.biodiversitydata.nl/xeno-canto/ob...       XC99998
#
#       basisOfRecord           collectionCode dynamicProperties  \
# 0  HumanObservation  Wildlife sounds - Birds               NaN
# 1  HumanObservation  Wildlife sounds - Birds               NaN
# 2  HumanObservation  Wildlife sounds - Birds               NaN
# 3  HumanObservation  Wildlife sounds - Birds               NaN
# 4  HumanObservation  Wildlife sounds - Birds               NaN
#
#   otherCatalogNumbers           genus specificEpithet infraspecificEpithet  \
# 0                 NaN      Synallaxis          azarae                media
# 1                 NaN          Turdus       hauxwelli                  NaN
# 2                 NaN      Myrmothera     campanisona              signata
# 3                 NaN      Glaucidium        peruanum                  NaN
# 4                 NaN  Eleoscytalopus     indigoticus                  NaN
#
#    ... verbatimEventDate                                         fieldNotes  \
# 0  ...        12-08-2002  two birds trip:http://www.cs.bris.ac.uk/home/p...
# 1  ...        01-10-2003   trip:http://www.cs.bris.ac.uk/home/planque/Peru/
# 2  ...        04-03-1998                                                NaN
# 3  ...          2011-7-5                                                NaN
# 4  ...        2011-10-14                                                NaN
#
#   behavior  sex lifeStage     preparations  \
# 0     song  NaN       NaN  field recording
# 1     song  NaN       NaN  field recording
# 2     song  NaN       NaN  field recording
# 3     song  NaN       NaN  field recording
# 4     song  NaN       NaN  field recording
#
#                                           references  \
# 0  https://data.biodiversitydata.nl/xeno-canto/ob...
# 1  https://data.biodiversitydata.nl/xeno-canto/ob...
# 2  https://data.biodiversitydata.nl/xeno-canto/ob...
# 3  https://data.biodiversitydata.nl/xeno-canto/ob...
# 4  https://data.biodiversitydata.nl/xeno-canto/ob...
#
#                                      Associated Taxa  \
# 0                                                NaN
# 1                                                NaN
# 2      has background sounds: Selenidera reinwardtii
# 3           has background sounds: Crypturellus soui
# 4  has background sounds: Pachyramphus castaneus|...
#
#                rightsHolder   license
# 0               Bob Planqué  CC BY-NC
# 1               Bob Planqué  CC BY-NC
# 2         Allen T. Chartier  CC BY-NC
# 3  Leonardo Ordóñez-Delgado  CC BY-NC
# 4         Rodrigo Dela Rosa  CC BY-NC
#
# [5 rows x 37 columns]

# %%
bird_occurrences.tail() # last n rows
# Out:
#                id                                       occurrenceID  \
# 697729   10000@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 697730  100003@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 697731  100002@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 697732  100001@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 697733  100000@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
#
#        catalogNumber     basisOfRecord           collectionCode  \
# 697729       XC10000  HumanObservation  Wildlife sounds - Birds
# 697730      XC100003  HumanObservation  Wildlife sounds - Birds
# 697731      XC100002  HumanObservation  Wildlife sounds - Birds
# 697732      XC100001  HumanObservation  Wildlife sounds - Birds
# 697733      XC100000  HumanObservation  Wildlife sounds - Birds
#
#        dynamicProperties otherCatalogNumbers         genus specificEpithet  \
# 697729               NaN                 NaN    Myrmothera     campanisona
# 697730               NaN                 NaN        Rallus       aquaticus
# 697731               NaN                 NaN  Crypturellus            soui
# 697732               NaN                 NaN   Nyctidromus      albicollis
# 697733               NaN                 NaN    Glaucidium        peruanum
#
#        infraspecificEpithet  ... verbatimEventDate  \
# 697729              signata  ...        04-03-1998
# 697730                  NaN  ...         2012-4-28
# 697731             harterti  ...          2011-7-5
# 697732           albicollis  ...          2011-7-5
# 697733                  NaN  ...          2011-7-5
#
#                                              fieldNotes behavior  sex  \
# 697729                           Responding to playback     song  NaN
# 697730  Aquatic Warbler and Spotted Crake in background     call  NaN
# 697731                 animal seen:no; playback used:no     song  NaN
# 697732                 animal seen:no; playback used:no     song  NaN
# 697733                 animal seen:no; playback used:no     song  NaN
#
#        lifeStage     preparations  \
# 697729       NaN  field recording
# 697730       NaN  field recording
# 697731       NaN  field recording
# 697732       NaN  field recording
# 697733       NaN  field recording
#
#                                                references  \
# 697729  https://data.biodiversitydata.nl/xeno-canto/ob...
# 697730  https://data.biodiversitydata.nl/xeno-canto/ob...
# 697731  https://data.biodiversitydata.nl/xeno-canto/ob...
# 697732  https://data.biodiversitydata.nl/xeno-canto/ob...
# 697733  https://data.biodiversitydata.nl/xeno-canto/ob...
#
#                                           Associated Taxa  \
# 697729                has background sounds: Cacicus cela
# 697730  has background sounds: Acrocephalus paludicola...
# 697731                                                NaN
# 697732                                                NaN
# 697733                                                NaN
#
#                     rightsHolder   license
# 697729         Allen T. Chartier  CC BY-NC
# 697730              Oliwier Myka  CC BY-NC
# 697731  Leonardo Ordóñez-Delgado  CC BY-NC
# 697732  Leonardo Ordóñez-Delgado  CC BY-NC
# 697733  Leonardo Ordóñez-Delgado  CC BY-NC
#
# [5 rows x 37 columns]

# %%
bird_occurrences.memory_usage(deep=True) # memory usage of each column in bytes
# Out:
# Index                          128
# id                        45970165
# occurrenceID              84345535
# catalogNumber             45272431
# basisOfRecord             50967814
# collectionCode            55818720
# dynamicProperties         27441300
# otherCatalogNumbers       22352014
# genus                     45784195
# specificEpithet           45808924
# infraspecificEpithet      26846382
# scientificName            53877997
# taxonRank                 45050100
# kingdom                   45352710
# family                    47128737
# higherClassification      62900605
# nomenclaturalCode         42561774
# identificationRemarks     22412186
# vernacularName            51743015
# longitudeDecimal           5581872
# latitudeDecimal            5581872
# geodeticDatum             42744318
# country                   45491542
# locality                  73080609
# verbatimElevation         43023987
# recordedBy                51490219
# eventDate                 46333183
# eventTime                 41367978
# verbatimEventDate         46677071
# fieldNotes               100018551
# behavior                  44981640
# sex                       27499774
# lifeStage                 26446936
# preparations              50213774
# references                84345535
# Associated Taxa           42937459
# rightsHolder              51490219
# license                   45352710
# dtype: int64

# %%
usage_by_col = bird_occurrences.memory_usage(deep=True) # returns memory usage for each column
total_usage = usage_by_col.sum()
mbs = total_usage / 1e6 # convert to megabytes
mbs
# Out:
# 1696.293981

# %%
bird_occurrences.isnull().any()
# Out:
# id                       False
# occurrenceID             False
# catalogNumber            False
# basisOfRecord            False
# collectionCode           False
# dynamicProperties         True
# otherCatalogNumbers       True
# genus                    False
# specificEpithet          False
# infraspecificEpithet      True
# scientificName           False
# taxonRank                False
# kingdom                  False
# family                   False
# higherClassification     False
# nomenclaturalCode        False
# identificationRemarks     True
# vernacularName           False
# longitudeDecimal          True
# latitudeDecimal           True
# geodeticDatum             True
# country                   True
# locality                  True
# verbatimElevation        False
# recordedBy               False
# eventDate                 True
# eventTime                 True
# verbatimEventDate         True
# fieldNotes                True
# behavior                  True
# sex                       True
# lifeStage                 True
# preparations              True
# references               False
# Associated Taxa           True
# rightsHolder             False
# license                  False
# dtype: bool

# %%
for col in bird_occurrences.columns:  # iterate over all columns
  if bird_occurrences[col].dtype not in [np.int64, np.float64]:  # ignore integer and float columns
    # print a header, all unique values, and a separator
    print('Unique Values for {}'.format(col))
    print(bird_occurrences[col].unique())
    print('')
# Out:
# Unique Values for id
# ['9@XC' '99@XC' '9999@XC' ... '100002@XC' '100001@XC' '100000@XC']
#
# Unique Values for occurrenceID
# ['https://data.biodiversitydata.nl/xeno-canto/observation/XC9'
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC99'
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC9999' ...
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC100002'
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC100001'
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC100000']
#
# Unique Values for catalogNumber
# ['XC9' 'XC99' 'XC9999' ... 'XC100002' 'XC100001' 'XC100000']
#
# Unique Values for basisOfRecord
# ['HumanObservation' 'MachineObservation']
#
# Unique Values for collectionCode
# ['Wildlife sounds - Birds']
#
# Unique Values for dynamicProperties
# [nan '{"recordingDevice":"Tascam DR-40X","microphone":"Sennheiser ME67"}'
#  '{"recordingDevice":"ICD-PX240"}' ...
#  '{"recordingDevice":"Sony PCM-M10","microphone":"Sennheiser ME66"}'
#  '{"recordingDevice":"Edirol R09-HR"}'
#  '{"recordingDevice":"Edirol R-09","microphone":"Sennheiser ME-66"}']
#
# Unique Values for otherCatalogNumbers
# [nan '01' '1' 'https://www.ornitho.de/index.php?m_id=54&id=27028870'
#  'https://www.ornitho.de/index.php?m_id=54&id=80580540'
#  'https://www.ornitho.de/index.php?m_id=54&id=80474035'
#  'https://www.ornitho.de/index.php?m_id=54&id=49584887'
#  'https://www.ornitho.de/index.php?m_id=54&id=40738693' '4C00829'
#  '4B00399' 'https://www.ornitho.de/index.php?m_id=54&id=59398800'
#  'https://www.ornitho.de/index.php?m_id=54&id=26421060'
#  'https://www.ornitho.de/index.php?m_id=54&id=65957165'
#  'https://www.ornitho.de/index.php?m_id=54&pnl=d&backlink=skip&id=59461563'
#  'https://www.ornitho.de/index.php?m_id=54&id=69279002' 'WA4994333'
#  'https://www.ornitho.de/index.php?m_id=54&id=48474308'
#  'https://www.ornitho.de/index.php?m_id=54&backlink=skip&mid=909353'
#  'https://www.ornitho.de/index.php?m_id=54&mid=57960' 'º'
#  'https://www.ornitho.de/index.php?m_id=54&mid=447056'
#  "Devil's cackle of a male" "Devil's cackle of a femele" '004' '003' '001'
#  '?' 'MBJSOARGOLOKA_AR03-2_Swift004_20230424' 'R00326' 'R00325' 'R00324'
#  'R00323' 'R00322' 'R00321' 'R00320' 'R00319' 'R00318' 'R00317'
#  'ZMUC 80163' '3' '2' 'R00316' 'R00315' 'R00314' '2-3' '3-4' 'R00313'
#  'R00312' 'R00311' 'R00310' 'R00309' 'R00308' 'R00307' 'R00306' 'R00305'
#  'R00304' 'R00303' 'R00302' 'R00301' 'R00300' 'R00299' 'R00298' 'R00297'
#  'R00296' 'R00295' 'R00294' 'R00293' 'R00292' 'R00291' 'R00290' 'R00289'
#  'R00288' 'R00287' 'R00286' 'R00285' 'R00284' 'R00283' 'SMM01892'
#  'тихчай_813_0837' 'китзел_813_0833' '15_03-13_Kultuk_Ccorax'
#  '2013_23_5_6_Storquata' '2013_05_19_6_Storquata' '2013_23_5_2'
#  'Желна_0783_26-07-2013_SH' 'Зеленый голубь _0761_21-07-2013_KUN'
#  'Камышовая овсянка _0740_20-07-2013_KUN'
#  'Чекан черногловый _0732_20-07-2013_KUN' '813_0742_20-07-2013_KUN'
#  'Маскированная овсянка _0649_14-07-2013_SH'
#  'Маскированная овсянка _0623_14-07-2013_SH'
#  'Маскированная овсянка _0622_14-07-2013_SH'
#  'Чернобровая камышевка  _0643_14-07-2013_SH'
#  'Чернобровая камышевка  _0640_14-07-2013_SH'
#  'Чернобровая камышевка   19_14-07-2013_SH'
#  'Черная ворона _0646_14-07-2013_SH' 'Черная ворона _0628_14-07-2013_SH'
#  'Соловей свистун  18_14-07-2013_SH' 'Чиж _0547_12-07-2013_SH'
#  'Таежный сверчок  2_12-07-2013_SH' 'Синий соловей _0559_12-07-2013_SH'
#  'Сизая овсянка _0574_12-07-2013_SH' 'Синехвостка 11_12-07-2013_SH'
#  'Синехвостка 10_12-07-2013_SH' 'Московка_0564_12-07-2013_SH'
#  'Московка _0595_12-07-2013_SH' 'Маскированная овсянка 1_12-07-2013_SH'
#  'Маскированная овсянка _0566_12-07-2013_SH'
#  'Маскированная овсянка  8_12-07-2013_SH'
#  'Малая синица _0516_12-07-2013_SH' 'Большая горлица _0588_12-07-2013_SH'
#  'Японская мухоловка _0554_12-07-2013_SH'
#  'Японская мухоловка _0553_12-07-2013_SH' 'Синий соловей  5_11-07-2013_SH'
#  'Синехвостка_0494_11-07-2013_SH' 'Синехвостка 4_11-07-2013_SH'
#  'Московка 3_11-07-2013_SH' 'Маскированная овсянка  2_11-07-2013_SH'
#  'Корольковая пеночка _0496_11-07-2013_SH'
#  'Конек зеленый  1_11-07-2013_SH' 'Большеклювая ворона 0472_11-07-2013_SH'
#  'Sound 17рыжий воробей' '5_06_94Phshvarcii 126' '5_06_94Phshvarcii 125'
#  '20_05_94bolshekluvaya 88_XII' '20_05_94korotkohvostka 2_XII'
#  '20_05_94sinyaia 1_XII' '21_05_94sinyaia 4_XII'
#  '21_05_94kitayskaya 8_XII' '21_05_94blednyi 9_XII'
#  '21_05_94beloglazki-lichinkoed 6_XII' '23_05_94shirokokluvaya 14_XII'
#  '23_05_94geltospinnaya 15_XII' '22_05_94blednyi 12_XII'
#  '22_05_94seryi 10_XII' '22_05_94Sound 13_XII' '31_05_94svetlogolovaya14'
#  '25_05_94geltogorlaya 92' '25_05_94gularis 18_XII'
#  '25_05_94nucifraga 20_XII' '25_05_94zarnichka 9_XII'
#  '25_05_94дроздtolstokluvaya 16_XII' '27_05_94_shirkuku 7'
#  '27_05_94ussurysn 8' '30_05_94pestrogolovaya13'
#  '30_05_94osheinikovaya 12' '4_06_94tolstokluvaya 224'
#  '4_06_94taegnyi 222' '4_06_94Sizyidr 221' '4_06_94geltospinnaya 223'
#  '2_06_94korolek 17' '2_06_94_taegnayaSound 18' 'June 15_2012__KBGD 20'
#  'June 15_2012__KBGD 19' 'Coturnix japonica_June 25_2012_Kuda 4'
#  'C_crex_June 28_2012_Kuda 1' 'C_crex_June 25_2012_Kuda_3' 'R00282'
#  'R00281' 'R00280' 'R00279' 'T4950_MB' 'R00278' 'R00277' 'R00276' 'R00275'
#  'R00274' 'R00273' 'R00272' 'R00271' 'R00270' 'R00269'
#  'Cicic_19920622_Dat13' 'Chloris chloris_20190418_T11sel' '2° - f ad'
#  '1° - f ad' '2°-GLC' 'https://observation.org/observation/263535540/'
#  '1(555)' '10' 'none' 'Universidad Nacional de Jujuy' '234560' '234559'
#  '234558' '221029_0520' '221028_0488' '221028_0489' '221025_0368' '234557'
#  '2345' '5' '4' 'No' 'no']
#
# Unique Values for genus
# ['Synallaxis' 'Turdus' 'Myrmothera' ... 'Palmeria' 'Grandala' 'Gymnoderus']
#
# Unique Values for specificEpithet
# ['azarae' 'hauxwelli' 'campanisona' ... 'cubanensis' 'foetidus'
#  'cristatella']
#
# Unique Values for infraspecificEpithet
# ['media' nan 'signata' ... 'pallida?' 'tempesti' 'Fulvescens']
#
# Unique Values for scientificName
# ['Synallaxis azarae media' 'Turdus hauxwelli'
#  'Myrmothera campanisona signata' ... 'Turdus poliocephalus tempesti'
#  'Zosterops ponapensis' 'Herpetotheres cachinnans Fulvescens']
#
# Unique Values for taxonRank
# ['subspecies' 'species']
#
# Unique Values for kingdom
# ['Animalia']
#
# Unique Values for family
# ['Furnariidae' 'Turdidae' 'Grallariidae' 'Strigidae' 'Rhinocryptidae'
#  'Alcedinidae' 'Icteridae' 'Psittacidae' 'Thamnophilidae' 'Paridae'
#  'Phylloscopidae' 'Aegithalidae' 'Locustellidae' 'Anatidae' 'Corvidae'
#  'Muscicapidae' 'Laridae' 'Acrocephalidae' 'Picidae' 'Scolopacidae'
#  'Passerellidae' 'Charadriidae' 'Bucerotidae' 'Hirundinidae' 'Emberizidae'
#  'Accipitridae' 'Trochilidae' 'Tyrannidae' 'Vireonidae' 'Sittidae'
#  'Fringillidae' 'Rallidae' 'Passeridae' 'Aegithinidae' 'Apodidae'
#  'Orthonychidae' 'Cettiidae' 'Mysteridae' 'Prunellidae' 'Pycnonotidae'
#  'Lybiidae' 'Phasianidae' 'Macrosphenidae' 'Cisticolidae' 'Malaconotidae'
#  'Ploceidae' 'Musophagidae' 'Platysteiridae' 'Tinamidae' 'Pipridae'
#  'Meropidae' 'Sarothruridae' 'Phoeniculidae' 'Stenostiridae' 'Oriolidae'
#  'Nicatoridae' 'Troglodytidae' 'Estrildidae' 'Motacillidae'
#  'Indicatoridae' 'Fregatidae' 'Columbidae' 'Sturnidae' 'Dicruridae'
#  'Nectariniidae' 'Coliidae' 'Galbulidae' 'Formicariidae' 'Cuculidae'
#  'Monarchidae' 'Glareolidae' 'Thraupidae' 'Parulidae' 'Trogonidae'
#  'Ardeidae' 'Recurvirostridae' 'Viduidae' 'Cardinalidae' 'Buphagidae'
#  'Regulidae' 'Alaudidae' 'Cracidae' 'Pellorneidae' 'Tityridae'
#  'Ramphastidae' 'Modulatricidae' 'Sylviidae' 'Upupidae' 'Zosteropidae'
#  'Podicipedidae' 'Caprimulgidae' 'Laniidae' 'Polioptilidae'
#  'Conopophagidae' 'Calyptomenidae' '26846.00' 'Leiothrichidae' 'Hyliidae'
#  'Certhiidae' 'Remizidae' 'Falconidae' 'Phoenicopteridae'
#  'Threskiornithidae' 'Vangidae' 'Paradisaeidae' 'Cotingidae'
#  'Melanopareiidae' 'Calcariidae' 'Semnornithidae' 'Phalacrocoracidae'
#  'Numididae' 'Campephagidae' 'Acanthizidae' 'Meliphagidae' 'Cacatuidae'
#  'Rhipiduridae' 'Corcoracidae' 'Climacteridae' 'Bucconidae' 'Burhinidae'
#  'Artamidae' 'Psittaculidae' 'Neosittidae' 'Ptilonorhynchidae' 'Menuridae'
#  'Maluridae' 'Pardalotidae' 'Momotidae' 'Pachycephalidae'
#  'Atrichornithidae' 'Dasyornithidae' 'Petroicidae' 'Megapodiidae'
#  'Pittidae' 'Dicaeidae' 'Podargidae' '14259.00' 'Spheniscidae'
#  'Odontophoridae' 'Timaliidae' 'Sapayoidae' '14435.00' 'Pomatostomidae'
#  'Procellariidae' 'Phaethontidae' 'Sulidae' 'Anhingidae' 'Jacanidae'
#  'Megalaimidae' 'Mimidae' 'Chloropseidae' 'Alcippeidae' 'Zeledoniidae'
#  'Coraciidae' 'Psophodidae' 'Ciconiidae' 'Peucedramidae' 'Capitonidae'
#  'Gruidae' 'Hemiprocnidae' 'Eurylaimidae' 'Psophiidae' '24673.00'
#  'Erythrocercidae' 'Haematopodidae' '10123.00' 'Bucorvidae' 'Anhimidae'
#  'Cariamidae' 'Aramidae' '8286.00' 'Donacobiidae' 'Mitrospingidae'
#  'Otididae' 'Nyctibiidae' 'Opisthocomidae' 'Eurypygidae' 'Todidae'
#  '19807.00' '24504.00' 'Pnoepygidae' '27390.00' 'Rhodinocichlidae'
#  'Paradoxornithidae' 'Bombycillidae' 'Diomedeidae' 'Pteroclidae'
#  'Ptiliogonatidae' '28138.00' 'Tytonidae' 'Eupetidae' 'Panuridae'
#  '21685.00' 'Leptosomidae' '24675.00' '5928.00' 'Gaviidae' 'Rheidae'
#  'Heliornithidae' 'Stercorariidae' 'Thinocoridae' 'Pluvianellidae'
#  '14266.00' 'Elachuridae' 'Strigopidae' 'Mohouidae' 'Apterygidae'
#  'Pityriasidae' 'Mesitornithidae' 'Bernieridae' 'Philepittidae'
#  'Pandionidae' 'Rostratulidae' 'Brachypteraciidae' 'Steatornithidae'
#  '32589.00' 'Scopidae' '14633.00' 'Icteriidae' 'Cinclidae' 'Scotocercidae'
#  'Acanthisittidae' 'Alcidae' 'Hydrobatidae' '30069.00' '27558.00'
#  'Environmentidae' 'Melampittidae' 'Struthionidae' '28159.00' '32094.00'
#  'Irenidae' 'Teretistridae' 'Spindalidae' '14431.00' 'Cinclosomatidae'
#  'Melanocharitidae' 'Casuariidae' 'Oreoicidae' 'Cnemophilidae'
#  'Pelecanidae' 'Oceanitidae' 'Turnicidae' 'Falcunculidae'
#  'Ibidorhynchidae' '27400.00' 'Chaetopidae' 'Cathartidae' 'Dromadidae'
#  'Callaeidae' 'Notiomystidae' '4600.00' '4059.00' 'Tichodromidae'
#  '9549.00' 'Anseranatidae' '25869.00' '21448.00' '23373.00' '703.00'
#  'Machaerirhynchidae' '14430.00' 'Dulidae' '22123.00' '13502.00'
#  '24725.00' 'Promeropidae' '19359.00' '4710.00' '18341.00' '4803.00'
#  '6122.00' 'Aegothelidae' 'Picathartidae' '14442.00' '14424.00' '32582.00'
#  'Ifritidae' '20424.00' '9553.00' '28398.00' '5691.00' 'Pluvianidae'
#  '21432.00' '14611.00' 'Hyliotidae' '4681.00' '8415.00' 'Calyptophilidae'
#  'Hypocoliidae' '20474.00' '3081.00' '17300.00' '17592.00' '23507.00'
#  'Urocynchramidae' '14423.00' '26490.00' '31041.00' '21620.00' '22686.00'
#  '30604.00' '27164.00' '3564.00' '22911.00' '12080.00' '12479.00'
#  '27753.00' '21480.00' 'Chionidae' 'Eulacestomatidae' 'Paramythiidae'
#  '14434.00' '4061.00' '20142.00' '20139.00' '25943.00' '28217.00'
#  '12474.00' '28017.00' 'Rhagologidae' '24021.00' '24265.00' '24283.00'
#  '21724.00' 'Hylocitreidae' '21851.00' 'Nesospingidae' 'Sagittariidae'
#  '27644.00' '11876.00' '30886.00' '10948.00' 'Phaenicophilidae' '14438.00'
#  '4833.00' '17459.00' '16619.00' '14433.00' '22909.00' '19711.00'
#  '9540.00' '20250.00' '11764.00' 'Rhynochetidae' '28086.00' '19794.00'
#  'Pedionomidae' '8257.00' '11042.00' '18742.00' '24284.00' '19080.00'
#  '18523.00' '19227.00' '24210.00' '17477.00']
#
# Unique Values for higherClassification
# ['Animalia|PASSERIFORMES|Furnariidae' 'Animalia|PASSERIFORMES|Turdidae'
#  'Animalia|PASSERIFORMES|Grallariidae' 'Animalia|STRIGIFORMES|Strigidae'
#  'Animalia|PASSERIFORMES|Rhinocryptidae'
#  'Animalia|CORACIIFORMES|Alcedinidae' 'Animalia|PASSERIFORMES|Icteridae'
#  'Animalia|PSITTACIFORMES|Psittacidae'
#  'Animalia|PASSERIFORMES|Thamnophilidae' 'Animalia|PASSERIFORMES|Paridae'
#  'Animalia|PASSERIFORMES|Phylloscopidae'
#  'Animalia|PASSERIFORMES|Aegithalidae'
#  'Animalia|PASSERIFORMES|Locustellidae' 'Animalia|ANSERIFORMES|Anatidae'
#  'Animalia|PASSERIFORMES|Corvidae' 'Animalia|PASSERIFORMES|Muscicapidae'
#  'Animalia|CHARADRIIFORMES|Laridae'
#  'Animalia|PASSERIFORMES|Acrocephalidae' 'Animalia|PICIFORMES|Picidae'
#  'Animalia|CHARADRIIFORMES|Scolopacidae'
#  'Animalia|PASSERIFORMES|Passerellidae'
#  'Animalia|CHARADRIIFORMES|Charadriidae'
#  'Animalia|BUCEROTIFORMES|Bucerotidae'
#  'Animalia|PASSERIFORMES|Hirundinidae'
#  'Animalia|PASSERIFORMES|Emberizidae'
#  'Animalia|ACCIPITRIFORMES|Accipitridae'
#  'Animalia|APODIFORMES|Trochilidae' 'Animalia|PASSERIFORMES|Tyrannidae'
#  'Animalia|PASSERIFORMES|Vireonidae' 'Animalia|PASSERIFORMES|Sittidae'
#  'Animalia|PASSERIFORMES|Fringillidae' 'Animalia|GRUIFORMES|Rallidae'
#  'Animalia|PASSERIFORMES|Passeridae' 'Animalia|PASSERIFORMES|Aegithinidae'
#  'Animalia|APODIFORMES|Apodidae' 'Animalia|PASSERIFORMES|Orthonychidae'
#  'Animalia|PASSERIFORMES|Cettiidae' 'Animalia|Mysteridae'
#  'Animalia|PASSERIFORMES|Prunellidae'
#  'Animalia|PASSERIFORMES|Pycnonotidae' 'Animalia|PICIFORMES|Lybiidae'
#  'Animalia|GALLIFORMES|Phasianidae'
#  'Animalia|PASSERIFORMES|Macrosphenidae'
#  'Animalia|PASSERIFORMES|Cisticolidae'
#  'Animalia|PASSERIFORMES|Malaconotidae' 'Animalia|PASSERIFORMES|Ploceidae'
#  'Animalia|MUSOPHAGIFORMES|Musophagidae'
#  'Animalia|PASSERIFORMES|Platysteiridae' 'Animalia|TINAMIFORMES|Tinamidae'
#  'Animalia|PASSERIFORMES|Pipridae' 'Animalia|CORACIIFORMES|Meropidae'
#  'Animalia|GRUIFORMES|Sarothruridae'
#  'Animalia|BUCEROTIFORMES|Phoeniculidae'
#  'Animalia|PASSERIFORMES|Stenostiridae' 'Animalia|PASSERIFORMES|Oriolidae'
#  'Animalia|PASSERIFORMES|Nicatoridae'
#  'Animalia|PASSERIFORMES|Troglodytidae'
#  'Animalia|PASSERIFORMES|Estrildidae'
#  'Animalia|PASSERIFORMES|Motacillidae' 'Animalia|PICIFORMES|Indicatoridae'
#  'Animalia|SULIFORMES|Fregatidae' 'Animalia|COLUMBIFORMES|Columbidae'
#  'Animalia|PASSERIFORMES|Sturnidae' 'Animalia|PASSERIFORMES|Dicruridae'
#  'Animalia|PASSERIFORMES|Nectariniidae' 'Animalia|COLIIFORMES|Coliidae'
#  'Animalia|PICIFORMES|Galbulidae' 'Animalia|PASSERIFORMES|Formicariidae'
#  'Animalia|CUCULIFORMES|Cuculidae' 'Animalia|PASSERIFORMES|Monarchidae'
#  'Animalia|CHARADRIIFORMES|Glareolidae'
#  'Animalia|PASSERIFORMES|Thraupidae' 'Animalia|PASSERIFORMES|Parulidae'
#  'Animalia|TROGONIFORMES|Trogonidae' 'Animalia|PELECANIFORMES|Ardeidae'
#  'Animalia|CHARADRIIFORMES|Recurvirostridae'
#  'Animalia|PASSERIFORMES|Viduidae' 'Animalia|PASSERIFORMES|Cardinalidae'
#  'Animalia|PASSERIFORMES|Buphagidae' 'Animalia|PASSERIFORMES|Regulidae'
#  'Animalia|PASSERIFORMES|Alaudidae' 'Animalia|GALLIFORMES|Cracidae'
#  'Animalia|PASSERIFORMES|Pellorneidae' 'Animalia|PASSERIFORMES|Tityridae'
#  'Animalia|PICIFORMES|Ramphastidae'
#  'Animalia|PASSERIFORMES|Modulatricidae'
#  'Animalia|PASSERIFORMES|Sylviidae' 'Animalia|BUCEROTIFORMES|Upupidae'
#  'Animalia|PASSERIFORMES|Zosteropidae'
#  'Animalia|PODICIPEDIFORMES|Podicipedidae'
#  'Animalia|CAPRIMULGIFORMES|Caprimulgidae'
#  'Animalia|PASSERIFORMES|Laniidae' 'Animalia|PASSERIFORMES|Polioptilidae'
#  'Animalia|PASSERIFORMES|Conopophagidae'
#  'Animalia|PASSERIFORMES|Calyptomenidae' 'Animalia|PASSERIFORMES|26846.00'
#  'Animalia|PASSERIFORMES|Leiothrichidae' 'Animalia|PASSERIFORMES|Hyliidae'
#  'Animalia|PASSERIFORMES|Certhiidae' 'Animalia|PASSERIFORMES|Remizidae'
#  'Animalia|FALCONIFORMES|Falconidae'
#  'Animalia|PHOENICOPTERIFORMES|Phoenicopteridae'
#  'Animalia|PELECANIFORMES|Threskiornithidae'
#  'Animalia|PASSERIFORMES|Vangidae' 'Animalia|PASSERIFORMES|Paradisaeidae'
#  'Animalia|PASSERIFORMES|Cotingidae'
#  'Animalia|PASSERIFORMES|Melanopareiidae'
#  'Animalia|PASSERIFORMES|Calcariidae' 'Animalia|PICIFORMES|Semnornithidae'
#  'Animalia|SULIFORMES|Phalacrocoracidae' 'Animalia|GALLIFORMES|Numididae'
#  'Animalia|PASSERIFORMES|Campephagidae'
#  'Animalia|PASSERIFORMES|Acanthizidae'
#  'Animalia|PASSERIFORMES|Meliphagidae'
#  'Animalia|PSITTACIFORMES|Cacatuidae'
#  'Animalia|PASSERIFORMES|Rhipiduridae'
#  'Animalia|PASSERIFORMES|Corcoracidae'
#  'Animalia|PASSERIFORMES|Climacteridae' 'Animalia|PICIFORMES|Bucconidae'
#  'Animalia|CHARADRIIFORMES|Burhinidae' 'Animalia|PASSERIFORMES|Artamidae'
#  'Animalia|PSITTACIFORMES|Psittaculidae'
#  'Animalia|PASSERIFORMES|Neosittidae'
#  'Animalia|PASSERIFORMES|Ptilonorhynchidae'
#  'Animalia|PASSERIFORMES|Menuridae' 'Animalia|PASSERIFORMES|Maluridae'
#  'Animalia|PASSERIFORMES|Pardalotidae' 'Animalia|CORACIIFORMES|Momotidae'
#  'Animalia|PASSERIFORMES|Pachycephalidae'
#  'Animalia|PASSERIFORMES|Atrichornithidae'
#  'Animalia|PASSERIFORMES|Dasyornithidae'
#  'Animalia|PASSERIFORMES|Petroicidae' 'Animalia|GALLIFORMES|Megapodiidae'
#  'Animalia|PASSERIFORMES|Pittidae' 'Animalia|PASSERIFORMES|Dicaeidae'
#  'Animalia|PODARGIFORMES|Podargidae' 'Animalia|PASSERIFORMES|14259.00'
#  'Animalia|SPHENISCIFORMES|Spheniscidae'
#  'Animalia|GALLIFORMES|Odontophoridae' 'Animalia|PASSERIFORMES|Timaliidae'
#  'Animalia|PASSERIFORMES|Sapayoidae' 'Animalia|PASSERIFORMES|14435.00'
#  'Animalia|PASSERIFORMES|Pomatostomidae'
#  'Animalia|PROCELLARIIFORMES|Procellariidae'
#  'Animalia|PHAETHONTIFORMES|Phaethontidae' 'Animalia|SULIFORMES|Sulidae'
#  'Animalia|SULIFORMES|Anhingidae' 'Animalia|CHARADRIIFORMES|Jacanidae'
#  'Animalia|PICIFORMES|Megalaimidae' 'Animalia|PASSERIFORMES|Mimidae'
#  'Animalia|PASSERIFORMES|Chloropseidae'
#  'Animalia|PASSERIFORMES|Alcippeidae'
#  'Animalia|PASSERIFORMES|Zeledoniidae' 'Animalia|CORACIIFORMES|Coraciidae'
#  'Animalia|PASSERIFORMES|Psophodidae' 'Animalia|CICONIIFORMES|Ciconiidae'
#  'Animalia|PASSERIFORMES|Peucedramidae' 'Animalia|PICIFORMES|Capitonidae'
#  'Animalia|GRUIFORMES|Gruidae' 'Animalia|APODIFORMES|Hemiprocnidae'
#  'Animalia|PASSERIFORMES|Eurylaimidae' 'Animalia|GRUIFORMES|Psophiidae'
#  'Animalia|PASSERIFORMES|24673.00'
#  'Animalia|PASSERIFORMES|Erythrocercidae'
#  'Animalia|CHARADRIIFORMES|Haematopodidae' 'Animalia|PICIFORMES|10123.00'
#  'Animalia|BUCEROTIFORMES|Bucorvidae' 'Animalia|ANSERIFORMES|Anhimidae'
#  'Animalia|CARIAMIFORMES|Cariamidae' 'Animalia|GRUIFORMES|Aramidae'
#  'Animalia|STRIGIFORMES|8286.00' 'Animalia|PASSERIFORMES|Donacobiidae'
#  'Animalia|PASSERIFORMES|Mitrospingidae' 'Animalia|OTIDIFORMES|Otididae'
#  'Animalia|NYCTIBIIFORMES|Nyctibiidae'
#  'Animalia|OPISTHOCOMIFORMES|Opisthocomidae'
#  'Animalia|EURYPYGIFORMES|Eurypygidae' 'Animalia|CORACIIFORMES|Todidae'
#  'Animalia|PASSERIFORMES|19807.00' 'Animalia|PASSERIFORMES|24504.00'
#  'Animalia|PASSERIFORMES|Pnoepygidae' 'Animalia|PASSERIFORMES|27390.00'
#  'Animalia|PASSERIFORMES|Rhodinocichlidae'
#  'Animalia|PASSERIFORMES|Paradoxornithidae'
#  'Animalia|PASSERIFORMES|Bombycillidae'
#  'Animalia|PROCELLARIIFORMES|Diomedeidae'
#  'Animalia|PTEROCLIFORMES|Pteroclidae'
#  'Animalia|PASSERIFORMES|Ptiliogonatidae'
#  'Animalia|PASSERIFORMES|28138.00' 'Animalia|STRIGIFORMES|Tytonidae'
#  'Animalia|PASSERIFORMES|Eupetidae' 'Animalia|PASSERIFORMES|Panuridae'
#  'Animalia|PASSERIFORMES|21685.00' 'Animalia|LEPTOSOMIFORMES|Leptosomidae'
#  'Animalia|PASSERIFORMES|24675.00' 'Animalia|CHARADRIIFORMES|5928.00'
#  'Animalia|GAVIIFORMES|Gaviidae' 'Animalia|RHEIFORMES|Rheidae'
#  'Animalia|GRUIFORMES|Heliornithidae'
#  'Animalia|CHARADRIIFORMES|Stercorariidae'
#  'Animalia|CHARADRIIFORMES|Thinocoridae'
#  'Animalia|CHARADRIIFORMES|Pluvianellidae'
#  'Animalia|PASSERIFORMES|14266.00' 'Animalia|PASSERIFORMES|Elachuridae'
#  'Animalia|PSITTACIFORMES|Strigopidae' 'Animalia|PASSERIFORMES|Mohouidae'
#  'Animalia|APTERYGIFORMES|Apterygidae'
#  'Animalia|PASSERIFORMES|Pityriasidae'
#  'Animalia|MESITORNITHIFORMES|Mesitornithidae'
#  'Animalia|PASSERIFORMES|Bernieridae'
#  'Animalia|PASSERIFORMES|Philepittidae'
#  'Animalia|ACCIPITRIFORMES|Pandionidae'
#  'Animalia|CHARADRIIFORMES|Rostratulidae'
#  'Animalia|CORACIIFORMES|Brachypteraciidae'
#  'Animalia|STEATORNITHIFORMES|Steatornithidae'
#  'Animalia|PASSERIFORMES|32589.00' 'Animalia|PELECANIFORMES|Scopidae'
#  'Animalia|PASSERIFORMES|14633.00' 'Animalia|PASSERIFORMES|Icteriidae'
#  'Animalia|PASSERIFORMES|Cinclidae' 'Animalia|PASSERIFORMES|Scotocercidae'
#  'Animalia|PASSERIFORMES|Acanthisittidae'
#  'Animalia|CHARADRIIFORMES|Alcidae'
#  'Animalia|PROCELLARIIFORMES|Hydrobatidae'
#  'Animalia|PASSERIFORMES|30069.00' 'Animalia|PASSERIFORMES|27558.00'
#  'Animalia|Environmentidae' 'Animalia|PASSERIFORMES|Melampittidae'
#  'Animalia|STRUTHIONIFORMES|Struthionidae'
#  'Animalia|PASSERIFORMES|28159.00' 'Animalia|PASSERIFORMES|32094.00'
#  'Animalia|PASSERIFORMES|Irenidae' 'Animalia|PASSERIFORMES|Teretistridae'
#  'Animalia|PASSERIFORMES|Spindalidae' 'Animalia|PASSERIFORMES|14431.00'
#  'Animalia|PASSERIFORMES|Cinclosomatidae'
#  'Animalia|PASSERIFORMES|Melanocharitidae'
#  'Animalia|CASUARIIFORMES|Casuariidae' 'Animalia|PASSERIFORMES|Oreoicidae'
#  'Animalia|PASSERIFORMES|Cnemophilidae'
#  'Animalia|PELECANIFORMES|Pelecanidae'
#  'Animalia|PROCELLARIIFORMES|Oceanitidae'
#  'Animalia|CHARADRIIFORMES|Turnicidae'
#  'Animalia|PASSERIFORMES|Falcunculidae'
#  'Animalia|CHARADRIIFORMES|Ibidorhynchidae'
#  'Animalia|PASSERIFORMES|27400.00' 'Animalia|PASSERIFORMES|Chaetopidae'
#  'Animalia|ACCIPITRIFORMES|Cathartidae'
#  'Animalia|CHARADRIIFORMES|Dromadidae' 'Animalia|PASSERIFORMES|Callaeidae'
#  'Animalia|PASSERIFORMES|Notiomystidae' 'Animalia|COLUMBIFORMES|4600.00'
#  'Animalia|COLUMBIFORMES|4059.00' 'Animalia|PASSERIFORMES|Tichodromidae'
#  'Animalia|CORACIIFORMES|9549.00' 'Animalia|ANSERIFORMES|Anseranatidae'
#  'Animalia|PASSERIFORMES|25869.00' 'Animalia|PASSERIFORMES|21448.00'
#  'Animalia|PASSERIFORMES|23373.00' 'Animalia|GALLIFORMES|703.00'
#  'Animalia|PASSERIFORMES|Machaerirhynchidae'
#  'Animalia|PASSERIFORMES|14430.00' 'Animalia|PASSERIFORMES|Dulidae'
#  'Animalia|PASSERIFORMES|22123.00' 'Animalia|PASSERIFORMES|13502.00'
#  'Animalia|PASSERIFORMES|24725.00' 'Animalia|PASSERIFORMES|Promeropidae'
#  'Animalia|PASSERIFORMES|19359.00' 'Animalia|COLUMBIFORMES|4710.00'
#  'Animalia|PASSERIFORMES|18341.00' 'Animalia|COLUMBIFORMES|4803.00'
#  'Animalia|CHARADRIIFORMES|6122.00'
#  'Animalia|AEGOTHELIFORMES|Aegothelidae'
#  'Animalia|PASSERIFORMES|Picathartidae' 'Animalia|PASSERIFORMES|14442.00'
#  'Animalia|PASSERIFORMES|14424.00' 'Animalia|PASSERIFORMES|32582.00'
#  'Animalia|PASSERIFORMES|Ifritidae' 'Animalia|PASSERIFORMES|20424.00'
#  'Animalia|CORACIIFORMES|9553.00' 'Animalia|PASSERIFORMES|28398.00'
#  'Animalia|CHARADRIIFORMES|5691.00' 'Animalia|CHARADRIIFORMES|Pluvianidae'
#  'Animalia|PASSERIFORMES|21432.00' 'Animalia|PASSERIFORMES|14611.00'
#  'Animalia|PASSERIFORMES|Hyliotidae' 'Animalia|COLUMBIFORMES|4681.00'
#  'Animalia|STRIGIFORMES|8415.00' 'Animalia|PASSERIFORMES|Calyptophilidae'
#  'Animalia|PASSERIFORMES|Hypocoliidae' 'Animalia|PASSERIFORMES|20474.00'
#  'Animalia|APODIFORMES|3081.00' 'Animalia|PASSERIFORMES|17300.00'
#  'Animalia|PASSERIFORMES|17592.00' 'Animalia|PASSERIFORMES|23507.00'
#  'Animalia|PASSERIFORMES|Urocynchramidae'
#  'Animalia|PASSERIFORMES|14423.00' 'Animalia|PASSERIFORMES|26490.00'
#  'Animalia|PASSERIFORMES|31041.00' 'Animalia|PASSERIFORMES|21620.00'
#  'Animalia|PASSERIFORMES|22686.00' 'Animalia|PASSERIFORMES|30604.00'
#  'Animalia|PASSERIFORMES|27164.00' 'Animalia|CUCULIFORMES|3564.00'
#  'Animalia|PASSERIFORMES|22911.00' 'Animalia|PSITTACIFORMES|12080.00'
#  'Animalia|PASSERIFORMES|12479.00' 'Animalia|PASSERIFORMES|27753.00'
#  'Animalia|PASSERIFORMES|21480.00' 'Animalia|CHARADRIIFORMES|Chionidae'
#  'Animalia|PASSERIFORMES|Eulacestomatidae'
#  'Animalia|PASSERIFORMES|Paramythiidae' 'Animalia|PASSERIFORMES|14434.00'
#  'Animalia|COLUMBIFORMES|4061.00' 'Animalia|PASSERIFORMES|20142.00'
#  'Animalia|PASSERIFORMES|20139.00' 'Animalia|PASSERIFORMES|25943.00'
#  'Animalia|PASSERIFORMES|28217.00' 'Animalia|PASSERIFORMES|12474.00'
#  'Animalia|PASSERIFORMES|28017.00' 'Animalia|PASSERIFORMES|Rhagologidae'
#  'Animalia|PASSERIFORMES|24021.00' 'Animalia|PASSERIFORMES|24265.00'
#  'Animalia|PASSERIFORMES|24283.00' 'Animalia|PASSERIFORMES|21724.00'
#  'Animalia|PASSERIFORMES|Hylocitreidae' 'Animalia|PASSERIFORMES|21851.00'
#  'Animalia|PASSERIFORMES|Nesospingidae'
#  'Animalia|ACCIPITRIFORMES|Sagittariidae'
#  'Animalia|PASSERIFORMES|27644.00' 'Animalia|PSITTACIFORMES|11876.00'
#  'Animalia|PASSERIFORMES|30886.00' 'Animalia|PICIFORMES|10948.00'
#  'Animalia|PASSERIFORMES|Phaenicophilidae'
#  'Animalia|PASSERIFORMES|14438.00' 'Animalia|COLUMBIFORMES|4833.00'
#  'Animalia|PASSERIFORMES|17459.00' 'Animalia|PASSERIFORMES|16619.00'
#  'Animalia|PASSERIFORMES|14433.00' 'Animalia|PASSERIFORMES|22909.00'
#  'Animalia|PASSERIFORMES|19711.00' 'Animalia|CORACIIFORMES|9540.00'
#  'Animalia|PASSERIFORMES|20250.00' 'Animalia|PSITTACIFORMES|11764.00'
#  'Animalia|EURYPYGIFORMES|Rhynochetidae' 'Animalia|PASSERIFORMES|28086.00'
#  'Animalia|PASSERIFORMES|19794.00' 'Animalia|CHARADRIIFORMES|Pedionomidae'
#  'Animalia|STRIGIFORMES|8257.00' 'Animalia|PICIFORMES|11042.00'
#  'Animalia|PASSERIFORMES|18742.00' 'Animalia|PASSERIFORMES|24284.00'
#  'Animalia|PASSERIFORMES|19080.00' 'Animalia|PASSERIFORMES|18523.00'
#  'Animalia|PASSERIFORMES|19227.00' 'Animalia|PASSERIFORMES|24210.00'
#  'Animalia|PASSERIFORMES|17477.00']
#
# Unique Values for nomenclaturalCode
# ['ICZN']
#
# Unique Values for identificationRemarks
# [nan 'identification questioned' 'identification unconfirmed']
#
# Unique Values for vernacularName
# ["Azara's Spinetail" "Hauxwell's Thrush" 'Thrush-like Antpitta' ...
#  'Crested Auklet' 'Black-breasted Weaver' 'Grey-brown White-eye']
#
# Unique Values for geodeticDatum
# ['WGS84' nan]
#
# Unique Values for country
# ['Ecuador' 'Peru' 'Brazil' 'Germany' 'France' 'United States' 'India'
#  'Cameroon' 'Lesotho' 'Belgium' 'Netherlands' 'Poland' 'United Kingdom'
#  'Australia' 'Papua New Guinea' 'Sweden' 'Spain' 'Colombia' 'Austria'
#  'Norway' 'Tanzania' 'Venezuela' 'Morocco' 'Czech Republic' 'Canada'
#  'Turkey' 'Taiwan' 'Italy' 'Indonesia' 'Switzerland' 'Kenya' 'Argentina'
#  'Honduras' 'Panama' 'Guyana' 'Cambodia' 'Denmark' 'Micronesia' 'Jamaica'
#  'Mexico' 'Uruguay' 'Costa Rica' 'Zambia' 'Fiji' 'Ghana' 'Thailand'
#  'Uganda' 'Latvia' 'South Sudan' 'Bolivia' 'Malaysia' 'Sri Lanka' 'China'
#  'Singapore' 'St Lucia' 'Rwanda' 'Sierra Leone' 'Mauritius' 'Puerto Rico'
#  'Myanmar' 'Russian Federation' 'Philippines' 'Madagascar' 'New Zealand'
#  'Iceland' 'East Timor' 'Chile' 'Vietnam' 'Bahamas' 'Mongolia'
#  'South Africa' 'Kazakhstan' 'Ethiopia' 'Trinidad & Tobago' 'South Korea'
#  'Guatemala' 'Hungary' 'Nicaragua' 'Bhutan' 'Ireland' 'Finland'
#  'French Guiana' 'Portugal' 'Slovakia' 'Congo (Brazzaville)' 'Japan'
#  'Nepal' 'Paraguay' 'Jordan' 'Laos' 'Estonia' 'Ukraine' 'Nigeria' 'Greece'
#  'Suriname' 'United Arab Emirates' 'Croatia' 'Israel' 'Serbia' 'Namibia'
#  'Guinea-Bissau' 'Bangladesh' 'Romania' 'Saudi Arabia' 'Botswana' 'Gabon'
#  'Cuba' 'Luxembourg' 'Mozambique' 'Georgia' 'Belarus' 'El Salvador'
#  'Angola' 'Solomon Islands' 'Bulgaria' 'Equatorial Guinea' 'Montenegro'
#  'Andorra' 'Slovenia' 'Congo (Democratic Republic)' 'Belize' 'Macedonia'
#  'Malawi' 'Lithuania' 'Armenia' nan 'Gambia' 'Zimbabwe'
#  'Dominican Republic' 'Liechtenstein' 'Barbados' 'Kuwait' 'Antarctica'
#  'Kyrgyzstan' 'Bosnia Herzegovina' 'Somalia' 'Pakistan' 'Albania'
#  'Algeria' 'Oman' 'Senegal' 'Uzbekistan' 'Egypt' 'Liberia' 'Azerbaijan'
#  'Cyprus' 'Iran' 'Ivory Coast' 'Tunisia' 'Guinea' 'Burkina Faso'
#  'Swaziland' 'Iraq' 'Mauritania' 'Brunei' 'Sao Tome'
#  'Antigua & Departments' 'Kiribati' 'Tajikistan' 'Tonga' 'Libya'
#  'Cape Verde' 'Burundi' 'Seychelles' 'Malta' 'Maldives' 'Bahrain'
#  'Central African Republic' 'Qatar' 'Vanuatu' 'Chad' 'Togo' 'mexico'
#  'Yemen' 'Lebanon' 'Niger' 'Moldova' 'Benin' 'St Vincent & Grenadines'
#  'Grenada' 'Mali' 'Dominica' 'Djibouti' 'Monaco' 'Turkmenistan' 'Comoros'
#  'Western Samoa' 'Syria' 'Nauru' 'Palau' 'Afghanistan']
#
# Unique Values for locality
# ['La Libertad, Cañar' 'Sachavacayoc Lodge, Tambopata'
#  'Sacha Lodge, Rio Napo, Orellana' ...
#  'Holly Beach, Cameron Par., Louisiana' 'SW Austin, Texas'
#  "Vallée de l'Hermeton"]
#
# Unique Values for verbatimElevation
# ['3000 m' '270 m' '250 m' ... '596 m' '1443 m' '29 m']
#
# Unique Values for recordedBy
# ['Bob Planqué' 'Allen T. Chartier' 'Leonardo Ordóñez-Delgado' ...
#  'Lennart Sandberg' 'Pat ODonnell' 'Sune Riis Sorensen']
#
# Unique Values for eventDate
# ['2002-08-12' '2003-10-01' '1998-03-04' ... '1993-09-14' '1998-12-09'
#  '1993-05-18']
#
# Unique Values for eventTime
# ['07:00' '08:25' nan ... '23:43' '01:17' '01:04']
#
# Unique Values for verbatimEventDate
# ['12-08-2002' '01-10-2003' '04-03-1998' ... '03-02-1998' '03-09-1998'
#  '2011-6-1']
#
# Unique Values for fieldNotes
# ['two birds trip:http://www.cs.bris.ac.uk/home/planque/Mazar/mazar-bird-report.html'
#  'trip:http://www.cs.bris.ac.uk/home/planque/Peru/' nan ...
#  'Bird rather distant; not seen.' 'In a mixed species flock.'
#  'Aquatic Warbler and Spotted Crake in background']
#
# Unique Values for behavior
# ['song' 'call' 'flight call' ... 'song, dusk song of a pair'
#  'call, distress calls of bird in the hand' 'song, two birds.']
#
# Unique Values for sex
# [nan 'male' 'female' 'undetermined' 'mixed']
#
# Unique Values for lifeStage
# [nan 'juvenile' 'uncertain' 'adult' 'adult, juvenile' 'adult, nestling'
#  'nestling' 'adult, juvenile, nestling' 'juvenile, nestling'
#  'adult, uncertain' 'juvenile, uncertain' 'adult, juvenile, uncertain'
#  'adult, nestling, uncertain' 'nestling, uncertain']
#
# Unique Values for preparations
# ['field recording' 'in the hand' 'unknown' nan 'in net'
#  'field recording, in the hand']
#
# Unique Values for references
# ['https://data.biodiversitydata.nl/xeno-canto/observation/XC9'
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC99'
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC9999' ...
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC100002'
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC100001'
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC100000']
#
# Unique Values for Associated Taxa
# [nan 'has background sounds: Selenidera reinwardtii'
#  'has background sounds: Crypturellus soui' ...
#  'has background sounds: Campylorhynchus fasciatus|Dives warczewiczi'
#  'has background sounds: Sittasomus griseicapillus|Trogon personatus'
#  'has background sounds: Patagioenas subvinacea|Cacicus cela']
#
# Unique Values for rightsHolder
# ['Bob Planqué' 'Allen T. Chartier' 'Leonardo Ordóñez-Delgado' ...
#  'Lennart Sandberg' 'Pat ODonnell' 'Sune Riis Sorensen']
#
# Unique Values for license
# ['CC BY-NC']

# %%
bird_occurrences.max()
# Out:
# <ipython-input-17-fb42b57a92ef>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   bird_occurrences.max()
# id                                                                   9@XC
# occurrenceID            https://data.biodiversitydata.nl/xeno-canto/ob...
# catalogNumber                                                     XC99999
# basisOfRecord                                          MachineObservation
# collectionCode                                    Wildlife sounds - Birds
# genus                                                         Zosterornis
# specificEpithet                                                 zosterops
# scientificName                       Zosterornis whiteheadi ss whiteheadi
# taxonRank                                                      subspecies
# kingdom                                                          Animalia
# family                                                       Zosteropidae
# higherClassification                    Animalia|TROGONIFORMES|Trogonidae
# nomenclaturalCode                                                    ICZN
# vernacularName                                           Zone-tailed Hawk
# longitudeDecimal                                                  179.918
# latitudeDecimal                                                   89.9417
# verbatimElevation                                            неизвестно m
# recordedBy                                                黄世桂shigui huang
# references              https://data.biodiversitydata.nl/xeno-canto/ob...
# rightsHolder                                              黄世桂shigui huang
# license                                                          CC BY-NC
# dtype: object

# %% [markdown]
# Note that the maximum verbatimElevation is "неизвестно m" which Google Translate says means "unknown m". Also, some of the values for verbatimElevation are "? m" (see min below)

# %%
bird_occurrences.min()
# Out:
# <ipython-input-18-5fa5e5bca677>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   bird_occurrences.min()
# id                                                              100000@XC
# occurrenceID            https://data.biodiversitydata.nl/xeno-canto/ob...
# catalogNumber                                                         XC1
# basisOfRecord                                            HumanObservation
# collectionCode                                    Wildlife sounds - Birds
# genus                                                            Abeillia
# specificEpithet                                                     aalge
# scientificName                                          Abeillia abeillei
# taxonRank                                                         species
# kingdom                                                          Animalia
# family                                                           10123.00
# higherClassification                Animalia|ACCIPITRIFORMES|Accipitridae
# nomenclaturalCode                                                    ICZN
# vernacularName                               'Fuscous Flycatcher sp.nov.'
# longitudeDecimal                                                 -179.992
# latitudeDecimal                                                  -86.9825
# verbatimElevation                                                   '?' m
# recordedBy                                       'Marco' Leslie Lieurance
# references              https://data.biodiversitydata.nl/xeno-canto/ob...
# rightsHolder                                     'Marco' Leslie Lieurance
# license                                                          CC BY-NC
# dtype: object

# %%
bird_occurrences['country'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
bird_occurrences['country'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='country'>

# %% [markdown]
# Second, let's do an Exploratory Data Analysis of the Multimedia file from the bird sounds dataset

# %%
# copy and paste file path between the quotation marks below
file_path = ''
bird_multimedia = pd.read_csv(file_path)
bird_multimedia.head()
# Out:
#   CoreId                     associatedObservationReference  \
# 0   9@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 1   9@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 2   9@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 3  99@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 4  99@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
#
#                                           Identifier        type  Rating  \
# 0  https://xeno-canto.org/sounds/uploaded/OH38YHK...  StillImage     NaN
# 1  https://xeno-canto.org/sounds/uploaded/OH38YHK...  StillImage     NaN
# 2  https://xeno-canto.org/sounds/uploaded/OH38YHK...       Sound     5.0
# 3  https://xeno-canto.org/sounds/uploaded/OH38YHK...  StillImage     NaN
# 4  https://xeno-canto.org/sounds/uploaded/OH38YHK...  StillImage     NaN
#
#                                rightsHolder  \
# 0  Stichting Xeno-canto voor Natuurgeluiden
# 1  Stichting Xeno-canto voor Natuurgeluiden
# 2                               Bob Planqué
# 3  Stichting Xeno-canto voor Natuurgeluiden
# 4  Stichting Xeno-canto voor Natuurgeluiden
#
#                                     creator  \
# 0  Stichting Xeno-canto voor Natuurgeluiden
# 1  Stichting Xeno-canto voor Natuurgeluiden
# 2                               Bob Planqué
# 3  Stichting Xeno-canto voor Natuurgeluiden
# 4  Stichting Xeno-canto voor Natuurgeluiden
#
#                                            accessURI     format  \
# 0  https://xeno-canto.org/sounds/uploaded/OH38YHK...  image/png
# 1  https://xeno-canto.org/sounds/uploaded/OH38YHK...  image/png
# 2  https://xeno-canto.org/sounds/uploaded/OH38YHK...  audio/mp3
# 3  https://xeno-canto.org/sounds/uploaded/OH38YHK...  image/png
# 4  https://xeno-canto.org/sounds/uploaded/OH38YHK...  image/png
#
#      variantLiteral description  \
# 0  ac:MediumQuality         NaN
# 1  ac:MediumQuality         NaN
# 2    ac:BestQuality        17 s
# 3  ac:MediumQuality         NaN
# 4  ac:MediumQuality         NaN
#
#                                              caption  \
# 0  Oscillogram of the first ten seconds of the so...
# 1  Spectrogram of the first ten seconds of the so...
# 2                                                NaN
# 3  Oscillogram of the first ten seconds of the so...
# 4  Spectrogram of the first ten seconds of the so...
#
#                            resourceCreationTechnique captureDevice  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2  automatic recording: no; bitrate: 64000 bps; b...           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
#
#   physicalSetting          license
# 0             NaN  CC BY-NC-SA 3.0
# 1             NaN  CC BY-NC-SA 3.0
# 2         Natural  CC BY-NC-SA 3.0
# 3             NaN  CC BY-NC-SA 3.0
# 4             NaN  CC BY-NC-SA 3.0

# %%
len(bird_multimedia['Identifier'].unique()) == len(bird_multimedia['Identifier'])
# Out:
# False

# %%
len(bird_multimedia['Identifier'].unique())
# Out:
# 2093174

# %%
len(bird_multimedia['Identifier'])
# Out:
# 2093238

# %%
len(bird_multimedia['accessURI'].unique()) == len(bird_multimedia['accessURI'])
# Out:
# False

# %%
len(bird_multimedia['accessURI'].unique())
# Out:
# 2093174

# %%
len(bird_multimedia['accessURI'])
# Out:
# 2093238

# %% [markdown]
# 'Identifier' and 'accessURI' both seem not to be indices, as they are not unique. However, the number of unique 'Identifier' values and the number of unique 'accessURI' values are the same...and as we see below, these seem to match up.

# %%
grouped_m = bird_multimedia.groupby(['Identifier', 'accessURI'])
grouped_m_counts = grouped_m.size().sort_values(ascending=False)
print(grouped_m_counts)
# Out:
# Identifier                                                                                                                                 accessURI
# https://xeno-canto.org/sounds/uploaded/JXZFXAZWHY/07.05.2023%20-%2006.24%20-%20U.epops.wav                                                 https://xeno-canto.org/sounds/uploaded/JXZFXAZWHY/07.05.2023%20-%2006.24%20-%20U.epops.wav                                                   5
# https://xeno-canto.org/sounds/uploaded/BTOFEKXFGW/MixPre-034.WAV                                                                           https://xeno-canto.org/sounds/uploaded/BTOFEKXFGW/MixPre-034.WAV                                                                             4
# https://xeno-canto.org/sounds/uploaded/JCPKCBKKAQ/ERIRUB_230618_3575_Paimpont35_Ronciere.mp3                                               https://xeno-canto.org/sounds/uploaded/JCPKCBKKAQ/ERIRUB_230618_3575_Paimpont35_Ronciere.mp3                                                 3
# https://xeno-canto.org/sounds/uploaded/BTOFEKXFGW/MixPre-001.WAV                                                                           https://xeno-canto.org/sounds/uploaded/BTOFEKXFGW/MixPre-001.WAV                                                                             3
# https://xeno-canto.org/sounds/uploaded/AFEHYCAHZR/Black-headedWoodpeckerEdwards.mp3                                                        https://xeno-canto.org/sounds/uploaded/AFEHYCAHZR/Black-headedWoodpeckerEdwards.mp3                                                          2
#                                                                                                                                                                                                                                                                                        ..
# https://xeno-canto.org/sounds/uploaded/JDGNAEDNHG/ffts/XC554011-large.png                                                                  https://xeno-canto.org/sounds/uploaded/JDGNAEDNHG/ffts/XC554011-large.png                                                                    1
# https://xeno-canto.org/sounds/uploaded/JDGNAEDNHG/XC554011-20200428%20Unkown%20BirdRecording%20Park%20Risdammerhout%20at%20Hoorn%20NL.mp3  https://xeno-canto.org/sounds/uploaded/JDGNAEDNHG/XC554011-20200428%20Unkown%20BirdRecording%20Park%20Risdammerhout%20at%20Hoorn%20NL.mp3    1
# https://xeno-canto.org/sounds/uploaded/JDFIQDKSPC/wave/XC761521-large.png                                                                  https://xeno-canto.org/sounds/uploaded/JDFIQDKSPC/wave/XC761521-large.png                                                                    1
# https://xeno-canto.org/sounds/uploaded/JDFIQDKSPC/ffts/XC761521-large.png                                                                  https://xeno-canto.org/sounds/uploaded/JDFIQDKSPC/ffts/XC761521-large.png                                                                    1
# https://xeno-canto.org/sounds/uploaded/ZZUMKXVPED/wave/XC840981-large.png                                                                  https://xeno-canto.org/sounds/uploaded/ZZUMKXVPED/wave/XC840981-large.png                                                                    1
# Length: 2093174, dtype: int64

# %%
grouped_m_identifier = bird_multimedia.groupby(['Identifier'])
grouped_m_identifier_counts = grouped_m_identifier.size().sort_values(ascending=False)
print(grouped_m_identifier_counts)
# Out:
# Identifier
# https://xeno-canto.org/sounds/uploaded/JXZFXAZWHY/07.05.2023%20-%2006.24%20-%20U.epops.wav                                                   5
# https://xeno-canto.org/sounds/uploaded/BTOFEKXFGW/MixPre-034.WAV                                                                             4
# https://xeno-canto.org/sounds/uploaded/JCPKCBKKAQ/ERIRUB_230618_3575_Paimpont35_Ronciere.mp3                                                 3
# https://xeno-canto.org/sounds/uploaded/BTOFEKXFGW/MixPre-001.WAV                                                                             3
# https://xeno-canto.org/sounds/uploaded/AFEHYCAHZR/Black-headedWoodpeckerEdwards.mp3                                                          2
#                                                                                                                                             ..
# https://xeno-canto.org/sounds/uploaded/JDGNAEDNHG/ffts/XC554011-large.png                                                                    1
# https://xeno-canto.org/sounds/uploaded/JDGNAEDNHG/XC554011-20200428%20Unkown%20BirdRecording%20Park%20Risdammerhout%20at%20Hoorn%20NL.mp3    1
# https://xeno-canto.org/sounds/uploaded/JDFIQDKSPC/wave/XC761521-large.png                                                                    1
# https://xeno-canto.org/sounds/uploaded/JDFIQDKSPC/ffts/XC761521-large.png                                                                    1
# https://xeno-canto.org/sounds/uploaded/ZZUMKXVPED/wave/XC840981-large.png                                                                    1
# Length: 2093174, dtype: int64

# %%
bird_multimedia.shape
# Out:
# (2074592, 16)

# %%
bird_multimedia.size
# Out:
# 33193472

# %%
bird_multimedia.columns
# Out:
# Index(['CoreId', 'associatedObservationReference', 'Identifier', 'type',
#        'Rating', 'rightsHolder', 'creator', 'accessURI', 'format',
#        'variantLiteral', 'description', 'caption', 'resourceCreationTechnique',
#        'captureDevice', 'physicalSetting', 'license'],
#       dtype='object')

# %%
bird_multimedia.dtypes
# Out:
# CoreId                             object
# associatedObservationReference     object
# Identifier                         object
# type                               object
# Rating                            float64
# rightsHolder                       object
# creator                            object
# accessURI                          object
# format                             object
# variantLiteral                     object
# description                        object
# caption                            object
# resourceCreationTechnique          object
# captureDevice                      object
# physicalSetting                    object
# license                            object
# dtype: object

# %%
bird_multimedia.tail()
# Out:
#             CoreId                     associatedObservationReference  \
# 2074587  100001@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 2074588  100001@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 2074589  100000@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 2074590  100000@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 2074591  100000@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
#
#                                                 Identifier        type  \
# 2074587  https://xeno-canto.org/sounds/uploaded/RJNSQXB...  StillImage
# 2074588  https://xeno-canto.org/sounds/uploaded/RJNSQXB...       Sound
# 2074589  https://xeno-canto.org/sounds/uploaded/RJNSQXB...  StillImage
# 2074590  https://xeno-canto.org/sounds/uploaded/RJNSQXB...  StillImage
# 2074591  https://xeno-canto.org/sounds/uploaded/RJNSQXB...       Sound
#
#          Rating                              rightsHolder  \
# 2074587     NaN  Stichting Xeno-canto voor Natuurgeluiden
# 2074588     5.0                  Leonardo Ordóñez-Delgado
# 2074589     NaN  Stichting Xeno-canto voor Natuurgeluiden
# 2074590     NaN  Stichting Xeno-canto voor Natuurgeluiden
# 2074591     5.0                  Leonardo Ordóñez-Delgado
#
#                                           creator  \
# 2074587  Stichting Xeno-canto voor Natuurgeluiden
# 2074588                  Leonardo Ordóñez-Delgado
# 2074589  Stichting Xeno-canto voor Natuurgeluiden
# 2074590  Stichting Xeno-canto voor Natuurgeluiden
# 2074591                  Leonardo Ordóñez-Delgado
#
#                                                  accessURI     format  \
# 2074587  https://xeno-canto.org/sounds/uploaded/RJNSQXB...  image/png
# 2074588  https://xeno-canto.org/sounds/uploaded/RJNSQXB...  audio/mp3
# 2074589  https://xeno-canto.org/sounds/uploaded/RJNSQXB...  image/png
# 2074590  https://xeno-canto.org/sounds/uploaded/RJNSQXB...  image/png
# 2074591  https://xeno-canto.org/sounds/uploaded/RJNSQXB...  audio/mp3
#
#            variantLiteral description  \
# 2074587  ac:MediumQuality         NaN
# 2074588    ac:BestQuality        60 s
# 2074589  ac:MediumQuality         NaN
# 2074590  ac:MediumQuality         NaN
# 2074591    ac:BestQuality        52 s
#
#                                                    caption  \
# 2074587  Spectrogram of the first ten seconds of the so...
# 2074588                                                NaN
# 2074589  Oscillogram of the first ten seconds of the so...
# 2074590  Spectrogram of the first ten seconds of the so...
# 2074591                                                NaN
#
#                                  resourceCreationTechnique captureDevice  \
# 2074587                                                NaN           NaN
# 2074588  automatic recording: no; bitrate: 64000 bps; b...           NaN
# 2074589                                                NaN           NaN
# 2074590                                                NaN           NaN
# 2074591  automatic recording: no; bitrate: 64000 bps; b...           NaN
#
#         physicalSetting          license
# 2074587             NaN  CC BY-NC-ND 2.5
# 2074588         Natural  CC BY-NC-ND 2.5
# 2074589             NaN  CC BY-NC-ND 2.5
# 2074590             NaN  CC BY-NC-ND 2.5
# 2074591         Natural  CC BY-NC-ND 2.5

# %%
bird_multimedia.memory_usage()
# Out:
# Index                                  128
# CoreId                            16596736
# associatedObservationReference    16596736
# Identifier                        16596736
# type                              16596736
# Rating                            16596736
# rightsHolder                      16596736
# creator                           16596736
# accessURI                         16596736
# format                            16596736
# variantLiteral                    16596736
# description                       16596736
# caption                           16596736
# resourceCreationTechnique         16596736
# captureDevice                     16596736
# physicalSetting                   16596736
# license                           16596736
# dtype: int64

# %%
bird_multimedia.isnull().any()
# Out:
# CoreId                            False
# associatedObservationReference    False
# Identifier                        False
# type                              False
# Rating                             True
# rightsHolder                      False
# creator                           False
# accessURI                         False
# format                            False
# variantLiteral                    False
# description                        True
# caption                            True
# resourceCreationTechnique          True
# captureDevice                      True
# physicalSetting                    True
# license                           False
# dtype: bool

# %%
for col in bird_multimedia.columns:  # iterate over all columns
  if bird_multimedia[col].dtype not in [np.int64, np.float64]:  # ignore integer and float columns
    # print a header, all unique values, and a separator
    print('Unique Values for {}'.format(col))
    print(bird_multimedia[col].unique())
    print('')
# Out:
# Unique Values for CoreId
# ['9@XC' '99@XC' '9999@XC' ... '100002@XC' '100001@XC' '100000@XC']
#
# Unique Values for associatedObservationReference
# ['https://data.biodiversitydata.nl/xeno-canto/observation/XC9'
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC99'
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC9999' ...
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC100002'
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC100001'
#  'https://data.biodiversitydata.nl/xeno-canto/observation/XC100000']
#
# Unique Values for Identifier
# ['https://xeno-canto.org/sounds/uploaded/OH38YHKJBS/wave/XC9-large.png'
#  'https://xeno-canto.org/sounds/uploaded/OH38YHKJBS/ffts/XC9-large.png'
#  'https://xeno-canto.org/sounds/uploaded/OH38YHKJBS/azaras_spinetail.mp3'
#  ...
#  'https://xeno-canto.org/sounds/uploaded/RJNSQXBIJE/wave/XC100000-large.png'
#  'https://xeno-canto.org/sounds/uploaded/RJNSQXBIJE/ffts/XC100000-large.png'
#  'https://xeno-canto.org/sounds/uploaded/RJNSQXBIJE/2.%20Glaucidium%20peruanum.mp3']
#
# Unique Values for type
# ['StillImage' 'Sound']
#
# Unique Values for rightsHolder
# ['Stichting Xeno-canto voor Natuurgeluiden' 'Bob Planqué'
#  'Allen T. Chartier' ... 'Lennart Sandberg' 'Pat ODonnell'
#  'Sune Riis Sorensen']
#
# Unique Values for creator
# ['Stichting Xeno-canto voor Natuurgeluiden' 'Bob Planqué'
#  'Allen T. Chartier' ... 'Lennart Sandberg' 'Pat ODonnell'
#  'Sune Riis Sorensen']
#
# Unique Values for accessURI
# ['https://xeno-canto.org/sounds/uploaded/OH38YHKJBS/wave/XC9-large.png'
#  'https://xeno-canto.org/sounds/uploaded/OH38YHKJBS/ffts/XC9-large.png'
#  'https://xeno-canto.org/sounds/uploaded/OH38YHKJBS/azaras_spinetail.mp3'
#  ...
#  'https://xeno-canto.org/sounds/uploaded/RJNSQXBIJE/wave/XC100000-large.png'
#  'https://xeno-canto.org/sounds/uploaded/RJNSQXBIJE/ffts/XC100000-large.png'
#  'https://xeno-canto.org/sounds/uploaded/RJNSQXBIJE/2.%20Glaucidium%20peruanum.mp3']
#
# Unique Values for format
# ['image/png' 'audio/mp3' 'audio/wav']
#
# Unique Values for variantLiteral
# ['ac:MediumQuality' 'ac:BestQuality']
#
# Unique Values for description
# [nan '17 s' '28 s' ... '1921 s' '1796 s' '1981 s']
#
# Unique Values for caption
# ['Oscillogram of the first ten seconds of the sound recording'
#  'Spectrogram of the first ten seconds of the sound recording' nan]
#
# Unique Values for resourceCreationTechnique
# [nan
#  'automatic recording: no; bitrate: 64000 bps; bitrate mode: cbr; audio sampling rate: 44100 Hz; number of channels: 1; lossy'
#  'automatic recording: no; bitrate: 102219 bps; bitrate mode: vbr; audio sampling rate: 44100 Hz; number of channels: 1; lossy'
#  ...
#  'automatic recording: no; bitrate: 99155 bps; bitrate mode: vbr; audio sampling rate: 44100 Hz; number of channels: 1; lossy'
#  'automatic recording: no; bitrate: 110708 bps; bitrate mode: vbr; audio sampling rate: 44100 Hz; number of channels: 1; lossy'
#  'automatic recording: no; bitrate: 109423 bps; bitrate mode: vbr; audio sampling rate: 44100 Hz; number of channels: 1; lossy']
#
# Unique Values for captureDevice
# [nan 'ICD-PX240 |' 'Marantz PMD661 MKIII | Sennheiser ME67' ...
#  'Sony PCM-M10 | Sennheiser ME66' 'Edirol R09-HR |'
#  'Edirol R-09 | Sennheiser ME-66']
#
# Unique Values for physicalSetting
# [nan 'Natural' 'Artificial' 'Natural, Artificial']
#
# Unique Values for license
# ['CC BY-NC-SA 3.0' 'CC BY-NC-ND 2.5' 'CC BY-SA 3.0' 'CC BY-NC-ND 4.0'
#  'CC BY-NC-ND 3.0' 'CC BY-SA 4.0' 'CC BY-NC-SA 4.0' 'CC0' 'CC BY-NC 4.0'
#  'CC BY 4.0']

# %%
bird_multimedia.max()
# Out:
# <ipython-input-39-b9964119c69f>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   bird_multimedia.max()
# CoreId                                                                         9@XC
# associatedObservationReference    https://data.biodiversitydata.nl/xeno-canto/ob...
# Identifier                        https://xeno-canto.org/sounds/uploaded/ZZUMKXV...
# type                                                                     StillImage
# Rating                                                                          5.0
# rightsHolder                                                        黄世桂shigui huang
# creator                                                             黄世桂shigui huang
# accessURI                         https://xeno-canto.org/sounds/uploaded/ZZUMKXV...
# format                                                                    image/png
# variantLiteral                                                     ac:MediumQuality
# license                                                                         CC0
# dtype: object

# %%
bird_multimedia.min()
# Out:
# <ipython-input-40-7c64d4b56683>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   bird_multimedia.min()
# CoreId                                                                    100000@XC
# associatedObservationReference    https://data.biodiversitydata.nl/xeno-canto/ob...
# Identifier                        https://xeno-canto.org/sounds/uploaded/AACMTXB...
# type                                                                          Sound
# Rating                                                                          1.0
# rightsHolder                                               'Marco' Leslie Lieurance
# creator                                                    'Marco' Leslie Lieurance
# accessURI                         https://xeno-canto.org/sounds/uploaded/AACMTXB...
# format                                                                    audio/mp3
# variantLiteral                                                       ac:BestQuality
# license                                                                   CC BY 4.0
# dtype: object

# %% [markdown]
# Let's do an Exploratory Data Analysis of the Data file from the World Bank dataset

# %%
file_path = '/content/drive/MyDrive/2023-24/CIS 5500/CIS 4500 5500 Project/raw data/WDI_CSV/WDICSV.csv'
world_bank_data = pd.read_csv(file_path)
world_bank_data.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014       2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  16.914625  17.392349  17.892005
# 1   NaN   NaN   NaN   NaN   NaN  ...   6.473301   6.720331   7.015917
# 2   NaN   NaN   NaN   NaN   NaN  ...  37.870347  38.184152  38.543180
# 3   NaN   NaN   NaN   NaN   NaN  ...  31.695183  31.859257  33.903515
# 4   NaN   NaN   NaN   NaN   NaN  ...  18.672306  17.623956  16.516633
#
#         2016       2017       2018       2019       2020       2021  2022
# 0  18.359993  18.795151  19.295176  19.788156  20.279599  20.773627   NaN
# 1   7.281390   7.513673   7.809566   8.075889   8.366010   8.684137   NaN
# 2  38.801719  39.039014  39.323186  39.643848  39.894830  40.213891   NaN
# 3  38.851444  40.197332  43.028332  44.389773  46.268621  48.103609   NaN
# 4  24.594474  25.389297  27.041743  29.138285  30.998687  32.772690   NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# Let's find out if 'Country Name' and 'Indicator Name' form an index of the dataset, as we might guess.

# %%
grouped_world_bank_data = world_bank_data.groupby(['Country Name', 'Indicator Name'])
counts = grouped_world_bank_data.size()
(counts == 1).all()
# Out:
# True

# %% [markdown]
# Yes, they do.

# %%
world_bank_data.shape
# Out:
# (392882, 68)

# %%
world_bank_data.size
# Out:
# 26715976

# %%
world_bank_data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        'Unnamed: 67'],
#       dtype='object')

# %%
world_bank_data.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2019              float64
# 2020              float64
# 2021              float64
# 2022              float64
# Unnamed: 67       float64
# Length: 68, dtype: object

# %%
world_bank_data.tail()
# Out:
#        Country Name Country Code  \
# 392877     Zimbabwe          ZWE
# 392878     Zimbabwe          ZWE
# 392879     Zimbabwe          ZWE
# 392880     Zimbabwe          ZWE
# 392881     Zimbabwe          ZWE
#
#                                            Indicator Name     Indicator Code  \
# 392877  Women who believe a husband is justified in be...     SG.VAW.REFU.ZS
# 392878  Women who were first married by age 15 (% of w...  SP.M15.2024.FE.ZS
# 392879  Women who were first married by age 18 (% of w...  SP.M18.2024.FE.ZS
# 392880  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
# 392881  Young people (ages 15-24) newly infected with HIV     SH.HIV.INCD.YG
#
#         1960  1961  1962  1963  1964  1965  ...     2014     2015     2016  \
# 392877   NaN   NaN   NaN   NaN   NaN   NaN  ...      NaN     14.5      NaN
# 392878   NaN   NaN   NaN   NaN   NaN   NaN  ...      NaN      3.7      NaN
# 392879   NaN   NaN   NaN   NaN   NaN   NaN  ...      NaN     32.4      NaN
# 392880   NaN   NaN   NaN   NaN   NaN   NaN  ...     59.4     59.5     59.7
# 392881   NaN   NaN   NaN   NaN   NaN   NaN  ...  19000.0  17000.0  15000.0
#
#            2017     2018    2019    2020    2021  2022  Unnamed: 67
# 392877      NaN      NaN     NaN     NaN     NaN   NaN          NaN
# 392878      NaN      NaN     5.4     NaN     NaN   NaN          NaN
# 392879      NaN      NaN    33.7     NaN     NaN   NaN          NaN
# 392880     59.9     60.1    60.3    60.5    60.7   NaN          NaN
# 392881  13000.0  10000.0  8600.0  7700.0  6800.0   NaN          NaN
#
# [5 rows x 68 columns]

# %%
world_bank_data.memory_usage()
# Out:
# Index                 128
# Country Name      3143056
# Country Code      3143056
# Indicator Name    3143056
# Indicator Code    3143056
#                    ...
# 2019              3143056
# 2020              3143056
# 2021              3143056
# 2022              3143056
# Unnamed: 67       3143056
# Length: 69, dtype: int64

# %%
world_bank_data.isnull().any()
# Out:
# Country Name      False
# Country Code      False
# Indicator Name    False
# Indicator Code    False
# 1960               True
#                   ...
# 2019               True
# 2020               True
# 2021               True
# 2022               True
# Unnamed: 67        True
# Length: 68, dtype: bool

# %%
for col in world_bank_data.columns:  # iterate over all columns
  if world_bank_data[col].dtype not in [np.int64, np.float64]:  # ignore integer and float columns
    # print a header, all unique values, and a separator
    print('Unique Values for {}'.format(col))
    print(world_bank_data[col].unique())
    print('')
# Out:
# Unique Values for Country Name
# ['Africa Eastern and Southern' 'Africa Western and Central' 'Arab World'
#  'Caribbean small states' 'Central Europe and the Baltics'
#  'Early-demographic dividend' 'East Asia & Pacific'
#  'East Asia & Pacific (excluding high income)'
#  'East Asia & Pacific (IDA & IBRD countries)' 'Euro area'
#  'Europe & Central Asia' 'Europe & Central Asia (excluding high income)'
#  'Europe & Central Asia (IDA & IBRD countries)' 'European Union'
#  'Fragile and conflict affected situations'
#  'Heavily indebted poor countries (HIPC)' 'High income' 'IBRD only'
#  'IDA & IBRD total' 'IDA blend' 'IDA only' 'IDA total'
#  'Late-demographic dividend' 'Latin America & Caribbean'
#  'Latin America & Caribbean (excluding high income)'
#  'Latin America & the Caribbean (IDA & IBRD countries)'
#  'Least developed countries: UN classification' 'Low & middle income'
#  'Low income' 'Lower middle income' 'Middle East & North Africa'
#  'Middle East & North Africa (excluding high income)'
#  'Middle East & North Africa (IDA & IBRD countries)' 'Middle income'
#  'North America' 'Not classified' 'OECD members' 'Other small states'
#  'Pacific island small states' 'Post-demographic dividend'
#  'Pre-demographic dividend' 'Small states' 'South Asia'
#  'South Asia (IDA & IBRD)' 'Sub-Saharan Africa'
#  'Sub-Saharan Africa (excluding high income)'
#  'Sub-Saharan Africa (IDA & IBRD countries)' 'Upper middle income' 'World'
#  'Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei Darussalam' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cabo Verde'
#  'Cambodia' 'Cameroon' 'Canada' 'Cayman Islands'
#  'Central African Republic' 'Chad' 'Channel Islands' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia' 'Denmark'
#  'Djibouti' 'Dominica' 'Dominican Republic' 'Ecuador' 'Egypt, Arab Rep.'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini'
#  'Ethiopia' 'Faroe Islands' 'Fiji' 'Finland' 'France' 'French Polynesia'
#  'Gabon' 'Gambia, The' 'Georgia' 'Germany' 'Ghana' 'Gibraltar' 'Greece'
#  'Greenland' 'Grenada' 'Guam' 'Guatemala' 'Guinea' 'Guinea-Bissau'
#  'Guyana' 'Haiti' 'Honduras' 'Hong Kong SAR, China' 'Hungary' 'Iceland'
#  'India' 'Indonesia' 'Iran, Islamic Rep.' 'Iraq' 'Ireland' 'Isle of Man'
#  'Israel' 'Italy' 'Jamaica' 'Japan' 'Jordan' 'Kazakhstan' 'Kenya'
#  'Kiribati' "Korea, Dem. People's Rep." 'Korea, Rep.' 'Kosovo' 'Kuwait'
#  'Kyrgyz Republic' 'Lao PDR' 'Latvia' 'Lebanon' 'Lesotho' 'Liberia'
#  'Libya' 'Liechtenstein' 'Lithuania' 'Luxembourg' 'Macao SAR, China'
#  'Madagascar' 'Malawi' 'Malaysia' 'Maldives' 'Mali' 'Malta'
#  'Marshall Islands' 'Mauritania' 'Mauritius' 'Mexico'
#  'Micronesia, Fed. Sts.' 'Moldova' 'Monaco' 'Mongolia' 'Montenegro'
#  'Morocco' 'Mozambique' 'Myanmar' 'Namibia' 'Nauru' 'Nepal' 'Netherlands'
#  'New Caledonia' 'New Zealand' 'Nicaragua' 'Niger' 'Nigeria'
#  'North Macedonia' 'Northern Mariana Islands' 'Norway' 'Oman' 'Pakistan'
#  'Palau' 'Panama' 'Papua New Guinea' 'Paraguay' 'Peru' 'Philippines'
#  'Poland' 'Portugal' 'Puerto Rico' 'Qatar' 'Romania' 'Russian Federation'
#  'Rwanda' 'Samoa' 'San Marino' 'Sao Tome and Principe' 'Saudi Arabia'
#  'Senegal' 'Serbia' 'Seychelles' 'Sierra Leone' 'Singapore'
#  'Sint Maarten (Dutch part)' 'Slovak Republic' 'Slovenia'
#  'Solomon Islands' 'Somalia' 'South Africa' 'South Sudan' 'Spain'
#  'Sri Lanka' 'St. Kitts and Nevis' 'St. Lucia' 'St. Martin (French part)'
#  'St. Vincent and the Grenadines' 'Sudan' 'Suriname' 'Sweden'
#  'Switzerland' 'Syrian Arab Republic' 'Tajikistan' 'Tanzania' 'Thailand'
#  'Timor-Leste' 'Togo' 'Tonga' 'Trinidad and Tobago' 'Tunisia' 'Turkiye'
#  'Turkmenistan' 'Turks and Caicos Islands' 'Tuvalu' 'Uganda' 'Ukraine'
#  'United Arab Emirates' 'United Kingdom' 'United States' 'Uruguay'
#  'Uzbekistan' 'Vanuatu' 'Venezuela, RB' 'Vietnam' 'Virgin Islands (U.S.)'
#  'West Bank and Gaza' 'Yemen, Rep.' 'Zambia' 'Zimbabwe']
#
# Unique Values for Country Code
# ['AFE' 'AFW' 'ARB' 'CSS' 'CEB' 'EAR' 'EAS' 'EAP' 'TEA' 'EMU' 'ECS' 'ECA'
#  'TEC' 'EUU' 'FCS' 'HPC' 'HIC' 'IBD' 'IBT' 'IDB' 'IDX' 'IDA' 'LTE' 'LCN'
#  'LAC' 'TLA' 'LDC' 'LMY' 'LIC' 'LMC' 'MEA' 'MNA' 'TMN' 'MIC' 'NAC' 'INX'
#  'OED' 'OSS' 'PSS' 'PST' 'PRE' 'SST' 'SAS' 'TSA' 'SSF' 'SSA' 'TSS' 'UMC'
#  'WLD' 'AFG' 'ALB' 'DZA' 'ASM' 'AND' 'AGO' 'ATG' 'ARG' 'ARM' 'ABW' 'AUS'
#  'AUT' 'AZE' 'BHS' 'BHR' 'BGD' 'BRB' 'BLR' 'BEL' 'BLZ' 'BEN' 'BMU' 'BTN'
#  'BOL' 'BIH' 'BWA' 'BRA' 'VGB' 'BRN' 'BGR' 'BFA' 'BDI' 'CPV' 'KHM' 'CMR'
#  'CAN' 'CYM' 'CAF' 'TCD' 'CHI' 'CHL' 'CHN' 'COL' 'COM' 'COD' 'COG' 'CRI'
#  'CIV' 'HRV' 'CUB' 'CUW' 'CYP' 'CZE' 'DNK' 'DJI' 'DMA' 'DOM' 'ECU' 'EGY'
#  'SLV' 'GNQ' 'ERI' 'EST' 'SWZ' 'ETH' 'FRO' 'FJI' 'FIN' 'FRA' 'PYF' 'GAB'
#  'GMB' 'GEO' 'DEU' 'GHA' 'GIB' 'GRC' 'GRL' 'GRD' 'GUM' 'GTM' 'GIN' 'GNB'
#  'GUY' 'HTI' 'HND' 'HKG' 'HUN' 'ISL' 'IND' 'IDN' 'IRN' 'IRQ' 'IRL' 'IMN'
#  'ISR' 'ITA' 'JAM' 'JPN' 'JOR' 'KAZ' 'KEN' 'KIR' 'PRK' 'KOR' 'XKX' 'KWT'
#  'KGZ' 'LAO' 'LVA' 'LBN' 'LSO' 'LBR' 'LBY' 'LIE' 'LTU' 'LUX' 'MAC' 'MDG'
#  'MWI' 'MYS' 'MDV' 'MLI' 'MLT' 'MHL' 'MRT' 'MUS' 'MEX' 'FSM' 'MDA' 'MCO'
#  'MNG' 'MNE' 'MAR' 'MOZ' 'MMR' 'NAM' 'NRU' 'NPL' 'NLD' 'NCL' 'NZL' 'NIC'
#  'NER' 'NGA' 'MKD' 'MNP' 'NOR' 'OMN' 'PAK' 'PLW' 'PAN' 'PNG' 'PRY' 'PER'
#  'PHL' 'POL' 'PRT' 'PRI' 'QAT' 'ROU' 'RUS' 'RWA' 'WSM' 'SMR' 'STP' 'SAU'
#  'SEN' 'SRB' 'SYC' 'SLE' 'SGP' 'SXM' 'SVK' 'SVN' 'SLB' 'SOM' 'ZAF' 'SSD'
#  'ESP' 'LKA' 'KNA' 'LCA' 'MAF' 'VCT' 'SDN' 'SUR' 'SWE' 'CHE' 'SYR' 'TJK'
#  'TZA' 'THA' 'TLS' 'TGO' 'TON' 'TTO' 'TUN' 'TUR' 'TKM' 'TCA' 'TUV' 'UGA'
#  'UKR' 'ARE' 'GBR' 'USA' 'URY' 'UZB' 'VUT' 'VEN' 'VNM' 'VIR' 'PSE' 'YEM'
#  'ZMB' 'ZWE']
#
# Unique Values for Indicator Name
# ['Access to clean fuels and technologies for cooking (% of population)'
#  'Access to clean fuels and technologies for cooking, rural (% of rural population)'
#  'Access to clean fuels and technologies for cooking, urban (% of urban population)'
#  ... 'Women who were first married by age 18 (% of women ages 20-24)'
#  "Women's share of population ages 15+ living with HIV (%)"
#  'Young people (ages 15-24) newly infected with HIV']
#
# Unique Values for Indicator Code
# ['EG.CFT.ACCS.ZS' 'EG.CFT.ACCS.RU.ZS' 'EG.CFT.ACCS.UR.ZS' ...
#  'SP.M18.2024.FE.ZS' 'SH.DYN.AIDS.FE.ZS' 'SH.HIV.INCD.YG']

# %%
print(world_bank_data['Indicator Name'].unique())
# Out:
# ['Access to clean fuels and technologies for cooking (% of population)'
#  'Access to clean fuels and technologies for cooking, rural (% of rural population)'
#  'Access to clean fuels and technologies for cooking, urban (% of urban population)'
#  ... 'Women who were first married by age 18 (% of women ages 20-24)'
#  "Women's share of population ages 15+ living with HIV (%)"
#  'Young people (ages 15-24) newly infected with HIV']

# %%
world_bank_data.max()
# Out:
# Country Name                                               Zimbabwe
# Country Code                                                    ZWE
# Indicator Name    Young people (ages 15-24) newly infected with HIV
# Indicator Code                              per_si_allsi.cov_q5_tot
# 1960                                             1629366714223830.0
#                                         ...
# 2019                                          5391344960000000000.0
# 2020                                         81449000000000000000.0
# 2021                                        431282000000000000000.0
# 2022                                       3083842125999999811584.0
# Unnamed: 67                                                     NaN
# Length: 68, dtype: object

# %%
world_bank_data.min()
# Out:
# Country Name                                            Afghanistan
# Country Code                                                    ABW
# Indicator Name    ARI treatment (% of children under 5 taken to ...
# Indicator Code                                       AG.AGR.TRAC.NO
# 1960                                             -259479537873292.0
#                                         ...
# 2019                                            -1155333853535490.0
# 2020                                            -2023638476248300.0
# 2021                                             -859571881033058.0
# 2022                                             -828988994120988.0
# Unnamed: 67                                                     NaN
# Length: 68, dtype: object
